# %% [markdown]
# # Classification Supervised Learning

# %% [markdown]
# ### The Classificaton in ML as the name suggests (Classifies) gives output of discrete values

# %% [markdown]
# ## => Different types of algorithm used in classification are:

# %% [markdown]
# <img height="400" src="Screenshot 2022-04-01 at 10.37.41 PM.png" width="900"/>

# %% [markdown]
# # Algorithm in detail:

# %% [markdown]
# ## 1. Logistic Regression
#
# ### It is used when the output may be Binary only
# ### It sets the best fit between the input and output changes at a point
#
# ### Mainly used in : INSURANCE RECOMMENDATION, DISEASE PREDICTION, WORD CLASSIFICATION

# %% [markdown]
# <img height="400" src="Screenshot 2022-04-01 at 11.28.20 PM.png" width="900"/>
