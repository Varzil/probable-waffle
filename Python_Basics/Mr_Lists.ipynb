# %% [markdown]
# ## Lists in python

# %%
# The lists in python
mylist=['varzil','is','programming']
print(mylist)
# Out:
# ['varzil', 'is', 'programming']

# %%
# we can also create list using the function
mylist2=list()
print(mylist2)
# Out:
# []

# %%
# We can store different data types in lists
mylist3=['gg',3,True]

# %%
print(mylist3)
# Out:
# ['gg', 3, True]
