# %% [markdown]
# # Name - Varzil Thakkar
# ## Roll No - 21BCP090
# ## Assisgnment 7

# %% [markdown]
# 1. Practice the examples provided in the ppt.
# 2. Draw two different plots in the same graph (multiple plots),
# consisting of following:
# a) Pie Chart
# b) Line Graph

# %% [markdown]
# ### Part 1:-

# %%
from matplotlib import pylab
